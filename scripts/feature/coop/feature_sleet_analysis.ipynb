# %%
# %matplotlib inline
import psycopg2
import datetime
import pytz
from pyiem.plot import MapPlot, nwssnow
import pandas as pd
import re
import numpy as np
from pyiem import iemre, reference

MAGRE = re.compile("(0\.[0-9][0-9]) INCH")
cmap = nwssnow()
clevs = np.array([0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.5])

# %%
txt = """"""

def get_lsrs(sts, ets):
    ''' Return snowfall lsrs '''
    POSTGIS = psycopg2.connect(database='postgis', host='localhost', port=5555, user='nobody')
    cursor = POSTGIS.cursor()
    data = []
    cursor.execute("""
    SELECT state, max(magnitude) as val, max(remark) as mcomment, ST_x(geom) as lon, ST_y(geom) as lat
    from lsrs WHERE typetext in ('ICE STORM', 'FREEZING RAIN') and 
    valid >= %s and valid < %s and wfo in ('FSD', 'MPX', 'ARX', 'DVN', 'EAX', 'OAX', 'DMX')
    GROUP by state, lon, lat
    """, (sts, ets))
    for i, row in enumerate(cursor):
        magnitude = row[1]
        if magnitude is None:
            t = MAGRE.findall(row[2])
            if len(t) == 0:
                print row[2]
            else:
                magnitude = float(t[0])
        if magnitude is None:
            continue
        data.append(dict(val=magnitude, comment=row[2], lat=row[4], lon=row[3],
                         label='l%s' % (i,), source='lsr', useme=True))
    
    cursor.close()
    POSTGIS.close()
    return data

sts = datetime.datetime(2017, 1, 16, 0)
sts = sts.replace(tzinfo=pytz.timezone("UTC"))
ets = datetime.datetime(2017, 1, 17, 18, 0)
ets = ets.replace(tzinfo=pytz.timezone("UTC"))
lrows = get_lsrs(sts, ets)

df = pd.DataFrame(lrows)
df.sort_values(by='val', ascending=False, inplace=True)
# Out:
# 0.4 TO 0.5 INCH ICE ACCUMULATION REPORTED WITH PICTURE VIA TWITTER.
# STORM TOTAL ICE AROUND ONE QUARTER INCH.
# STORM TOTAL ICE AROUND ONE QUARTER INCH.
# APPROXIMATELY 3/16 INCH ICE ACCUMULATION. PHOTO AND REPORT SUBMITTED VIA SOCIAL MEDIA.
# ICE ACCUMULATION ON EXPOSED SURFACES GENERALLY AROUND 1/8 INCH BUT UP TO 1/4 INCH ON THE GROUND IN SOME SPOTS. AT NWS OAX.
# ICE UP TO 3/8 OF AN INCH THICK ON SOME EXPOSED SURFACES.
# 0.25-0.4 INCHES OF ESTIMATED ICE ACCUMULATION. VIA TWITTER
# 0.32" ICE ACCUMULATION STORM TOTAL AS OF 18Z.

# %%
# Now we filter the DataFrame
radii = [0.6, 0.9, 1.2]  # decimal degrees

df['useme'] = False
newrows = []
for lon in np.arange(reference.IA_WEST, reference.IA_EAST, radii[0]):
    for lat in np.arange(reference.IA_SOUTH, reference.IA_NORTH, radii[0]):
        hit = False
        for radius in radii:
            west = lon - (radius / 2.)
            east = lon + (radius / 2.)
            south = lat - (radius / 2.)
            north = lat + (radius / 2.)
            df2 = df[(df['lat'] >= south) & (df['lat'] < north) &
                     (df['lon'] >= west) & (df['lon'] < east)]
            if len(df2.index) > 0:
                df.at[df2.index, 'useme'] = False
                df.at[df2.index[0], 'useme'] = True
                hit = True
                break
        if not hit:
            newrows.append(dict(val=0, lat=lat, lon=lon, label='i%s' % (len(newrows),), source='int', useme=True))
            continue
if len(newrows) > 0:
    df = df.append(newrows)
df.set_index('label', inplace=True)

# %%
cull = ['l115', 'l14', 'l95', 'l56', 'i7', 'i1', 'l33', 'l93', 'i0', 'i3', 'i5', 'i2',
       'i4', 'i6', 'l31', 'l97']
if len(cull) > 0:
    df.at[cull, 'useme'] = False


m = MapPlot(figsize=(20,18), sector='midwest')
df2 = df[df.useme]
m.contourf(df2.lon.values, df2.lat.values, df2.val.values, clevs, cmap=cmap)
m.plot_values(df2['lon'], df2['lat'], df2['val'], '%.2f', labels=df2.index.values, textsize=20,
              labeltextsize=20, labelbuffer=5)

# %%
# now we are ready to plot!

m = MapPlot(sector='iowa',
            title='15-16 Jan 2017 - IEM Freezing Rain Total Analysis',
            subtitle="** Heavily Smoothed, Contains Estimates ** NWS Local Storm Reports of Ice through 8 PM 16 January 2017")
m.contourf(df2.lon.values, df2.lat.values, df2.val.values, clevs, cmap=cmap)
#m.plot_values(np.array(df2.lon), np.array(df2.lat), np.array(df2.val), '%.2f')
m.drawcounties()
m.drawcities()
m.postprocess(filename='170117.png')
