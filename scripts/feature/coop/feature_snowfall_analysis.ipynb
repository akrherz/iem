# %%
import psycopg2
import datetime
import pytz
from pyiem.plot import MapPlot
import pandas as pd
import numpy as np
import iemplot
# Out:
# /usr/lib64/python2.6/site-packages/matplotlib/__init__.py:1155: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
def get_lsrs(sts, ets):
    ''' Return snowfall lsrs '''
    POSTGIS = psycopg2.connect(database='postgis', host='iemdb', user='nobody')
    cursor = POSTGIS.cursor()
    data = []
    cursor.execute("""
    SELECT state, max(magnitude) as val, ST_x(geom) as lon, ST_y(geom) as lat
    from lsrs WHERE type in ('S') and magnitude > 0 and 
    valid >= %s and valid < %s
    GROUP by state, lon, lat
    """, (sts, ets))
    for i, row in enumerate(cursor):
        data.append(dict(val=row[1], lat=row[3], lon=row[2], label='l%s' % (i,), source='lsr', useme=True))
    
    cursor.close()
    POSTGIS.close()
    return data

def get_coop(dates):
    ''' Return snowfall obs for the given dates '''
    if len(dates) == 1:
        dates.append( dates[0] )
    IEM = psycopg2.connect(database='iem', host='iemdb', user='nobody')
    cursor = IEM.cursor()
    data = []
    cursor.execute("""
    WITH obs as (
        SELECT s.iemid, count(*), sum(snow) from summary s JOIN stations t on (t.iemid = s.iemid)
        WHERE t.network in ('IACOCORAHS','IA_COOP') and s.day in """+str(tuple(dates))+""" 
        and snow >= 0 GROUP by s.iemid
    )
    SELECT id, obs.count, obs.sum, ST_x(geom), ST_y(geom), county from stations JOIN obs
    on (obs.iemid = stations.iemid)
    """)
    for row in cursor:
        data.append(dict(val=row[2], lat=row[4], lon=row[3], label=row[0], source='coop', useme=True))
    
    cursor.close()
    IEM.close()
    return data

crows = get_coop( ['2014-02-05', '2014-02-06'] )
sts = datetime.datetime(2014,2,5,6,0)
sts = sts.replace(tzinfo=pytz.timezone("UTC"))
ets = datetime.datetime(2014,2,5,23,0)
ets = ets.replace(tzinfo=pytz.timezone("UTC"))
lrows = get_lsrs(sts, ets)

df = pd.DataFrame(crows + lrows)

# %%
for i, row in df.iterrows():
    if row['label'] in ('IA-GN-1','ATLI4', 'LSXI4') or row['val'] > 20 or row['source'] == 'lsr22':
        df['useme'][i] = False
    else:
        df['useme'][i] = True
m = MapPlot(figsize=(20,18))
df2 = df[df.useme]
m.contourf(np.array(df2.lon), np.array(df2.lat), np.array(df2.val), np.arange(0,6,0.25))
m.plot_values(df2['lon'], df2['lat'], df2['val'], '%.2f', labels=df2.label)

# %%
# now we are ready to plot!
clevs = np.array([0.01,0.1,0.25,0.5,1,2,3,5,7,9,11,13,15,17])
m = MapPlot(sector='iowa',
            title="4 Feb - 5 Feb 2014 - IEM Snowfall Total Analysis",
            subtitle="Snowfall totals up until 8 AM 5 Feb 2014")
cmap = cm.get_cmap('Spectral_r')
cmap.set_over('black')
cmap.set_under('white')
m.contourf(np.array(df2.lon), np.array(df2.lat), np.array(df2.val), clevs, cmap=cmap)
m.drawcounties()
m.postprocess(filename='test.ps')
iemplot.makefeature('test')
