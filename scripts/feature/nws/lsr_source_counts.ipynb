# %%
import psycopg2
import datetime
import pytz
import numpy as np
POSTGIS = psycopg2.connect(database='postgis', host='iemdb', user='nobody')
cursor = POSTGIS.cursor()

data = {}

cursor.execute("""
  SELECT extract(year from valid) as yr, 
  upper(source) as up, 
  count(*) from lsrs WHERE valid > '2006-01-01'
  GROUP by yr, up ORDER by yr ASC
  """)
yeartotals = [0]*9
for row in cursor:
    if not data.has_key(row[0]):
        data[row[0]] = {}
    yeartotals[int(row[0])-2006] += row[2]
    data[row[0]][row[1]] = row[2] 
    
POSTGIS.close()

# %%
top10 = ['TRAINED SPOTTER',                  
 'PUBLIC',                           
 'LAW ENFORCEMENT',                  
 'CO-OP OBSERVER',                   
 'EMERGENCY MNGR',                   
 'MESONET',   
 'COCORAHS',
 'AMATEUR RADIO',                   
 'BROADCAST MEDIA',
 'NWS EMPLOYEE',
 'SOCIAL MEDIA',
 'FACEBOOK']
labels = []
y = []

for year in range(2006,2015):
    row = []
    sums = 0
    for t in top10:
        p = data[year].get(t, 0) / float(yeartotals[year-2006]) * 100.
        if year == 2014:
            labels.append("%s %.1f%%" % (t, p))
        row.append( p )
        sums += data[year].get(t, 0)
    p = (float(yeartotals[year-2006]) - sums) / float(yeartotals[year-2006]) * 100.
    row.append( p)
    if year == 2014:
        labels.append("(OTHER) %.1f%%" % (p,))
    y.append(row)

# %%
y = np.array(y)

import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
plt.rc('axes', color_cycle=['r', 'g', 'b', 'y', 'c', 'darkorange', 'k', 'khaki', 
                            'purple', 'salmon', 'lavender',
                            'olive', '#EEEEEE'])
fig = plt.figure(figsize=(12,8))
ax = plt.axes([0.1,0.1,0.5,0.8])
stack_coll = ax.stackplot(range(2006,2015), y[:,0], y[:,1], y[:,2], y[:,3], y[:,4], y[:,5], y[:,6]
             , y[:,7], y[:,8], y[:,9], y[:,10], y[:,11], y[:,12])
# make proxy artists
proxy_rects = [Rectangle((0, 0), 1, 1, fc=pc.get_facecolor()[0]) for pc in stack_coll[::-1]]
# make the legend
ax.legend(proxy_rects, labels[::-1], ncol=1, fontsize=14, loc=(1,0.0))
ax.set_xticks(range(2006,2015))
ax.set_xticklabels([str(s) for s in range(2006,2015)], fontsize=18)
ax.set_ylim(0,100)
ax.set_yticks(range(0,101,10))
ax.set_title("1 Jan 2005 - 12 Aug 2014 NWS Local Storm Report Source Type (2014 % labelled)")
ax.set_xlabel("Based on unofficial Iowa Environmental Mesonet Archives @akrherz")
ax.set_ylabel("Percentage of Reports for Year [%]", fontsize=18)
ax.grid(True)
fig.savefig('test.png', dpi=100)
