# %%
import iemdb
POSTGIS = iemdb.connect('postgis', bypass=True)
pcursor = POSTGIS.cursor()
ASOS = iemdb.connect('asos', bypass=True)
acursor = ASOS.cursor()

from matplotlib import pyplot as plt

# %%
def get_asos(sts, ets):
    acursor.execute("""SELECT valid, vsby, sknt, gust,
    case when gust > sknt then gust else sknt end from t"""+`sts.year`+"""
 WHERE station = 'DSM' and valid BETWEEN %s and %s ORDER by valid ASC""",
                    (sts.strftime("%Y-%m-%d %H:%M"), ets.strftime("%Y-%m-%d %H:%M")))
    valid = []
    vsby = []
    sknt = []
    gust = []
    for row in acursor:
        valid.append( row[0]) 
        vsby.append( row[1] )
        sknt.append( row[2] )
        gust.append( row[4] * 1.15)
        
    return valid, vsby, sknt, gust

# %%
import matplotlib.dates as mdates
from matplotlib.patches import Rectangle

import iemtz
(fig, ax) = plt.subplots(5,1, figsize=(6,12))
pcursor.execute("""select issue, expire from warnings where ugc = 'IAZ060' and wfo = 'DMX' 
  and phenomena = 'BZ' and significance = 'W' 
  and expire > issue and issue > '2009-01-01' ORDER by issue DESC""")

i = 0
for row in pcursor:
    valid, vsby, sknt, gust = get_asos(row[0], row[1])
    print i, len(valid)
    ax[i].plot(valid, vsby, color='b', zorder=2)
    ax[i].set_ylabel("Visibility [mile]", color='b')
    ax2 = ax[i].twinx()
    ax2.plot(valid, gust, color='r', zorder=2)
    ax2.set_ylabel("Wind Gust [mph]", color='r')
    
    ax[i].set_ylim(0,10)
    ax2.set_ylim(0,60)
    
    ax[i].xaxis.set_major_locator(
                               mdates.DayLocator(interval=1,
                                                 tz=iemtz.Central)
                               )
    ax[i].xaxis.set_major_formatter(mdates.DateFormatter('|\n%d %b %Y',
                                                      tz=iemtz.Central))

    ax[i].xaxis.set_minor_locator(
                               mdates.HourLocator(interval=5,
                                                 tz=iemtz.Central)
                               )
    ax[i].xaxis.set_minor_formatter(mdates.DateFormatter('%I %p',
                                                      tz=iemtz.Central))
    ax[i].grid(True)
    
    for j in range(1,len(valid)):
        if vsby[j] <= 0.25 and gust[j] >= 35:
            rect = plt.Rectangle((valid[j-1],0),(valid[j]-valid[j-1]).seconds / (24.0 *1440.0), 60, 
 fc='#EEEEEE', zorder=1) 
            ax[i].add_patch(rect)
    i += 1
ax[0].set_title("Des Moines Blizzard Warnings [2009-2012]\nDes Moines Airport Data") 
ax[4].set_xlabel("Shaded areas <1/4 mile vis & 35+ MPH winds")
fig.tight_layout()
# Out:
# 0 65
# 1
#  28
# 2
#  68
# 3
#  18
# 4
#  20

# %%
fig.savefig('test.ps')
